# %%
x = 52633
for i in range(2, x):
    if x % i == 0:
        print(i)
# Out:
# 7
# 73
# 103
# 511
# 721
# 7519

# %%
def print_factor(x):
    for i in range(2, x):
        if x % i == 0:
            print(i)

print_factor(52633)
# Out:
# 7
# 73
# 103
# 511
# 721
# 7519

# %%
l = [52633, 8137, 1024, 999]
for num in l:
    print_factor(num)
# Out:
# 7
# 73
# 103
# 511
# 721
# 7519
# 79
# 103
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 3
# 9
# 27
# 37
# 111
# 333
